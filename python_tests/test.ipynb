# %%
import json
import os
import sys

# %%
# list all json files in the directory python_tests
# just list the json files
# just list the json files in the format of test_*.json
# just list the json files in the format of test_*.json and sort them
list_of_files = [f for f in os.listdir("./") if f.endswith(".json") and f.startswith("test_") and "output" not in f]


data = []
for i, j in enumerate(list_of_files):
    with (open(j, "r")) as f:
        data.append(json.load(f))

for i, j in enumerate(data):
    for k, l in enumerate(j["data"]["result"]["data"]["elementPeriods"]):
        for m, n in enumerate(j["data"]["result"]["data"]["elementPeriods"][l]):
            print(n["id"])
# Out:
# 687077
# 687082
# 687087
# 687092
# 688707
# 688712
# 689407
# 689412
# 689417
# 689422
# 691037
# 691042
# 692197
# 692202
# 692207
# 692212
# 694047
# 694052
# 694057
# 694062
# 695802
# 695807
# 695812
# 697082
# 697087
# 698242
# 698247
# 698252
# 698257
# 699182
# 699187
# 699192
# 699197
# 699882
# 699887
# 700812
# 700817
# 701512
# 701517
# 701522
# 701527
# 703362
# 703367
# 703372
# 703377
# 705002
# 705007
# 705932
# 705937
# 706862
# 706867
# 1018427
# 1049542
# 728617
# 728622
# 728632
# 728637
# 1029180
# 1029185
# 1029190
# 1029195
# 1029590
# 1029690
# 730822
# 730827
# 730832
# 730837
# 732682
# 732687
# 732692
# 732697
# 734542
# 734547
# 734552
# 734557
# 748317
# 748322
# 748327
# 748332
# 802122
# 802127
# 802132
# 802137
# 803992
# 803997
# 804002
# 804007
# 804922
# 804927
# 804932
# 804937
# 806792
# 806797
# 806802
# 806807
# 808662
# 808667
# 808672
# 808677
# 828267
# 828272
# 828277
# 828282
# 829437
# 829442
# 858767
# 858772
# 859927
# 859932
# 859937
# ...
